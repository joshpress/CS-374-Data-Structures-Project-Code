# %% [markdown]
# # Installing libraries if needed
#
# This project utilizes Pandas for the data generation and loading of CSV files, as well as NetworkX for the graphs.
# Pyvis is used to render the graphs in an HTML file.

# %%
# %pip install pandas networkx pyvis ipython
from IPython.display import display, HTML

# %% [markdown]
# # Creating Dataset

# %%
from createDataset import *

top_500_branch_50=createDataset(500,50)

# %%
top_500_branch_50

# %% [markdown]
# # Loading Dataset and creating Knowledge Graph

# %% [markdown]
# ## Loading in CSVs

# %%
from createKnowledgeGraph import *

testGraph=KnowledgeGraph('top_50_branch_10.csv')
top15000Graph=KnowledgeGraph('top_15000_branch_10.csv')

# %% [markdown]
# ## renderGraph

# %%
testGraph.renderGraph(font_size=12)

# %%
display(HTML('knowledge_graph.html'))

# %% [markdown]
# ## query

# %%
top15000Graph.query("computer",search_limit=10,neighbor_limit=3,directed=True)

# %%
display(HTML('query_subgraph.html'))
